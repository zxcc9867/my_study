# %% [markdown]
# <a href="https://colab.research.google.com/github/zxcc9867/my_study/blob/main/%5B%EC%8B%A4%EC%8A%B5%EC%9A%A9%5D_Selena_%EC%8B%A4%ED%8C%A8_%EC%97%86%EC%9D%B4_%EC%99%84%EC%A3%BC%ED%95%98%EB%8A%94_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_%EC%9E%85%EB%AC%B8_STEP9_%EC%98%88%EC%99%B8%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [공지사항]
# * 제작 과정에서 강의명이 변경되어 영상 및 강의 자료에 표기된 강의명은 촬영 시점에 사용된 것으로, 강의 내용에는 변동이 없음을 안내드리오며 수강에 혼선 없으시길 바랍니다.

# %% [markdown]
# ![슬라이드1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # STEP 9. 예외 처리

# %% [markdown]
# ![슬라이드2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## **01. 오류**
# - 파이썬의 오류는 두 가지 종류 존재
# > - 구문 오류
# > - 예외 (런타임 오류)

# %% [markdown]
# ![슬라이드3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. 구문 오류**
# - 프로그램 실행 전에 발생하는 오류

# %%
# 문자열 닫힘 따옴표 문제로 오류 발생
# SyntaxError는 구문에 문제가 있어서 프로그램이 실행조차 안 된 경우

# %%
# 문자열 닫힘 따옴표 문제를 해결하여 오류 해결
# 해당 오류는 해결을 해줘야만 프로그램을 실행할 수 있음

# %% [markdown]
# ![슬라이드4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. 예외 (런타임 오류)**
# - 프로그램 실행 중에 발생하는 오류

# %%
# myList 변수에 리스트 선언 -> 프로그램 실행됨
# myList[7]은 myList에서 얻을 수 없는 값으로 오류 발생

# %%
# myList 변수에 리스트 선언 -> 프로그램 실행됨
# myList[3]은 myList에서 얻을 수 있는 값으로 수정하여 오류 해결
# 또는 예외 처리를 통해 문제를 해결할 수 있음!

# %% [markdown]
# ![슬라이드5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## **02. 예외 처리 기법**
# - 예외 처리는 예외를 해결하는 것
# - 프로그램이 강제로 종료되는 일 없이 예외 처리를 하고 정상적으로 종료

# %% [markdown]
# ![슬라이드6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. try - except 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# 프로그램이 강제로 종료되는 일 없이 예외 처리를 하고 정상적으로 종료

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# except 문 안에 pass 키워드를 넣으면 아무것도 출력하지 않고 강제 종료도 막을 수 있음

# %% [markdown]
# ![슬라이드7.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. try - except - else 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# 문자 입력 시 예외 발생

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# 숫자 입력시 프로그램 정상 작동

# %% [markdown]
# ![슬라이드8.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. try - except - finally 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 문자 입력 시 예외 발생

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 숫자 입력시 프로그램 정상 작동

# %% [markdown]
# ![슬라이드9.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **4. try - except - else - finally 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 문자 입력 시 예외 발생

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 숫자 입력시 프로그램 정상 작동

# %% [markdown]
# # **자기 주도 학습 복습 과제 - 문제**
# * 문제를 풀고 답을 확인하세요 :)
# * 정답지에 자세히 설명되어 있습니다.
# * [정답지 링크](https://drive.google.com/file/d/1Nsgxb04bRzsdZXKVZmsCqX6bnZIRIQdl/view?usp=sharing)

# %% [markdown]
# ## **1. 예외 처리 문제 (1)**
#
# * try, except, else, finally 구문

# %%
# 1) try, except, else, finally 구문을 이용하여 예외처리 구현
#   - 'myList' 변수에 0, 1, 2, 3 요소를 통해 리스트 선언
#   - 'myList'의 8번째 인덱스를 호출하여 myListEighth 변수에 저장
#   - 예외가 발생하면 "예외가 발생하였습니다." 문자열 출력
#   - 예외가 발생하지 않는다면 "myList[8]의 값은 'myListEighth' 입니다." 문자열 출력하고 myListEighth는 변수 값 삽입
try :


except :

else :

finally :
  print("실패 없이 완주하는 파이썬 데이터 분석 입문 과정의 Part 1. 파이썬 기본기 다지기를 모두 마치셨어요!")
  print("정말 고생하셨어요!! :) 같이 파이썬 라이브러리 활용 배우러 가요~! 우리의 목표는 완!강! :)")

# %%
# 2) try, except, else, finally 구문을 이용하여 예외처리 구현
#   - 'myList' 변수에 0, 1, 2, 3, 4, 5, 6, 7, 8 요소를 통해 리스트 선언
#   - 'myList'의 8번째 인덱스를 호출하여 myListEighth 변수에 저장
#   - 예외가 발생하면 "예외가 발생하였습니다." 문자열 출력
#   - 예외가 발생하지 않는다면 "myList[8]의 값은 'myListEighth' 입니다." 문자열 출력하고 myListEighth는 변수 값 삽입
try :


except :

else :

finally :
  print("실패 없이 완주하는 파이썬 데이터 분석 입문 과정의 Part 1. 파이썬 기본기 다지기를 모두 마치셨어요!")
  print("정말 고생하셨어요!! :) 같이 파이썬 라이브러리 활용 배우러 가요~! 우리의 목표는 완!강! :)")
